# %% [markdown]
# <a href="https://colab.research.google.com/github/VICO-27/Data-Science-Foundation-/blob/main/python_foundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Foundations Assignment
# Author: Ashenafi Deresa
#
# This notebook contains solutions for:
# 1. Factorial of a number
# 2. Fibonacci sequence generator
# 3. CLI Calculator

# %% [markdown]
# ## Level 1: Compute the Factorial of a Number
# Factorial means multiplying a number by all positive integers below it.
# Example: 5! = 5 × 4 × 3 × 2 × 1 = 120

# %%
def factorial(n):
    if n < 0:
        return "Factorial not defined for negative numbers"

    result = 1
    for i in range(1, n + 1):
        result *= i

    return result


num = int(input("Enter a number: "))
print("Factorial:", factorial(num))
# Out:
# Enter a number: 5
# Factorial: 120

# %% [markdown]
# ## Level 2: Generate Fibonacci Sequence
# The Fibonacci sequence starts with 0 and 1. Each next number is the sum of the previous two.

# %%
def fibonacci(n):
    sequence = []
    a, b = 0, 1

    for _ in range(n):
        sequence.append(a)
        a, b = b, a + b

    return sequence


terms = int(input("Enter number of terms: "))
print("Fibonacci sequence:", fibonacci(terms))
# Out:
# Enter number of terms: 7
# Fibonacci sequence: [0, 1, 1, 2, 3, 5, 8]

# %% [markdown]
# ## Level 3: CLI Calculator
# This calculator performs basic arithmetic operations using functions.

# %%
def add(a, b):
    return a + b


def subtract(a, b):
    return a - b


def multiply(a, b):
    return a * b


def divide(a, b):
    if b == 0:
        return "Cannot divide by zero"
    return a / b


print("Simple Calculator")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

choice = input("Choose operation: ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == "1":
    print("Result:", add(num1, num2))

elif choice == "2":
    print("Result:", subtract(num1, num2))

elif choice == "3":
    print("Result:", multiply(num1, num2))

elif choice == "4":
    print("Result:", divide(num1, num2))

else:
    print("Invalid operation")
# Out:
# Simple Calculator
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Choose operation: 4
# Enter first number: 10
# Enter second number: 3
# Result: 3.3333333333333335
